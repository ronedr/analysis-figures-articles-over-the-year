# %% [markdown]
# # Classify Figures to Type by The Model Trained on Part of Data:

# %%
from keras.models import load_model
model = load_model('image_classification_model_with_vgg16.h5')

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from PIL import Image

# Define constants
target_size = (224, 224)
num_classes = 9  # Change this to the number of classes in your dataset

# Load the trained model
model = load_model('image_classification_model_with_vgg16.h5')  # Load your trained model

# Load and preprocess a single image
def preprocess_single_image(image_path):
    image = Image.open(image_path)
    if image.mode != "RGB":
        image = image.convert("RGB")
    image = image.resize(target_size)
    image = np.array(image) / 255.0
    return np.expand_dims(image, axis=0)

# Predict on a single image
def predict_single_image(image_path):
    processed_image = preprocess_single_image(image_path)
    prediction = model.predict(processed_image)
    predicted_class = np.argmax(prediction)
    return predicted_class

# %%
import pandas as pd

figures_df = pd.read_csv("./figures_articles_with_path_with_colors.csv")
figures_df
# Out:
#        year  article_id figure_name  \
# 0      2010     5169847     Fig. 1.
# 1      2010     5169847     Fig. 2.
# 2      2010     5169847     Fig. 3.
# 3      2010     5169847     Fig. 4.
# 4      2010     5169847     Fig. 5.
# ...     ...         ...         ...
# 10762  2023    10121783   FIGURE 1.
# 10763  2023    10121783   FIGURE 2.
# 10764  2023    10121783   FIGURE 3.
# 10765  2023    10121783   FIGURE 4.
# 10766  2023    10121783   FIGURE 5.
#
#                                           figure_caption  \
# 0                        Block diagram of the RF device.
# 1      Percentile variability explained by each princ...
# 2      Projection of devices onto the top three princ...
# 3      Zoom in the core of functional devices in the ...
# 4      Test error (i.e., average number of misclassif...
# ...                                                  ...
# 10762            Overview of the different FL scenarios.
# 10763  Overview of the operations executed by a node ...
# ...

# %%
figures_df["figure_category"] = figures_df["figure_path"].apply(lambda image_path: predict_single_image(image_path))
# Out:
# ...
# 1/1 [==============================] - 0s 292ms/step
# ...
# ...
# 1/1 [==============================] - 7s 7s/step

# %%
type_num_to_type_name = {0: "bar_graphs", 1: "code", 2: "diagrams", 3: "heatmap", 4: "images", 5: "line_graphs", 6: "others", 7: "pie_graphs", 8: "scatter_plot"}

# %%
figures_df["figure_category_name"] = figures_df["figure_category"].apply(lambda cat_num: type_num_to_type_name[cat_num])

# %%
figures_df.to_csv("./figures_articles_with_path_with_colors_with_type.csv", index=False)

# %% [markdown]
# # Evaluate The Classifier

# %%
for i in range(10):
    random_row = figures_df.sample()
    # Load the image from the URL using PIL
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    response = requests.get(random_row["figure_img"].values[0], headers=headers)
    image_data = response.content
    image = Image.open(BytesIO(image_data))

    # Display the image using matplotlib
    plt.title(random_row["figure_category_name"].values[0])
    plt.imshow(image)
    plt.axis('off')  # Turn off axis labels and ticks
    plt.show()
